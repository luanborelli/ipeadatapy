# %%
import ipeadatapy as idpy

# %% [markdown]
# # Basic Usage Overview

# %% [markdown]
# <img src="fluxogram.png" />

# %% [markdown]
# ### Plans for this notebook:
#
# 1. **BEGINNER: Exploring Available Time Series**
#     - 1.1. Having an Overview of a Time Series
#     - 1.2. Checking Time Series' Data
#
# 2. **INTERMEDIATE: Exploring Ipeadata Metadata**
#     - 2.1. Advanced Filtering Using Metadata
#
# 3. **Extracting Data**
#
# 4. **ADVANCED: Doing from Scratch**

# %% [markdown]
# # 1. BEGINNER: Exploring Available Time Series

# %% [markdown]
# To start, let's list all Ipeadata's time series:

# %%
idpy.list_series()
# Out:
#                    CODE                                               NAME
# 0          ABATE_ABPEAV            Abate - aves - peso das carcaças - qde.
# 1          ABATE_ABPEBV         Abate - bovinos - peso das carcaças - qde.
# 2          ABATE_ABPESU          Abate - suínos - peso das carcaças - qde.
# 3          ABATE_ABQUAV                                Abate - aves - qde.
# 4          ABATE_ABQUBV                             Abate - bovinos - qde.
# 5          ABATE_ABQUSU                              Abate - suínos - qde.
# 6      ABATE12_ABPEAV12            Abate - aves - peso das carcaças - qde.
# 7      ABATE12_ABPEBO12            Abate - bois - peso das carcaças - qde.
# 8      ABATE12_ABPEBV12         Abate - bovinos - peso das carcaças - qde.
# 9      ABATE12_ABPEFR12         Abate - frangos - peso das carcaças - qde.
# 10     ABATE12_ABPENO12        Abate - novilhos - peso das carcaças - qde.
# 11     ABATE12_ABPESU12          Abate - suínos - peso das carcaças - qde.
# 12     ABATE12_ABPEVA12           Abate - vacas - peso das carcaças - qde.
# 13     ABATE12_ABPEVI12         Abate - vitelos - peso das carcaças - qde.
# 14     ABATE12_ABQUAV12                                Abate - aves - qde.
# 15     ABATE12_ABQUBO12                                Abate - bois - qde.
# 16     ABATE12_ABQUBV12                             Abate - bovinos - qde.
# 17     ABATE12_ABQUFR12                             Abate - frangos - qde.
# 18     ABATE12_ABQUNO12                            Abate - novilhos - qde.
# 19     ABATE12_ABQUSU12                              Abate - suínos - qde.
# 20     ABATE12_ABQUVA12                               Abate - vacas - qde.
# 21     ABATE12_ABQUVI12                             Abate - vitelos - qde.
# 22        ABIA12_ALIM12  Produção física - alimentos - índice (média 19...
# 23       ABPO12_PAPEL12  Expedição de caixas, acessórios e chapas - pap...
# 24    ABRACAL_PCALCARIO                Produção - calcário agrícola - qde.
# 25      ANATEL_APARELHO                    Telefone - aparelhos instalados
# 26          ANATEL_INST                Telefone - acessos fixos instalados
# 27          ANATEL_SERV                Telefone - acessos fixos em serviço
# 28       ANATEL_SERVMOV               Telefone - acessos móveis em serviço
# 29    ANATEL_SERVMOVFIX       Telefone - acessos móveis e fixos em serviço
# ...                 ...                                                ...
# 8563             PIBCNE  PIB Estadual - indústria - construção - valor ...
# 8564              PIBCO  PIB Municipal - serviços - comércio - valor ad...
# 8565             PIBCOE  PIB Estadual - serviços - comércio - valor adi...
# 8566               PIBE                   PIB Estadual a preços constantes
# 8567            PIBEGAE  PIB Estadual - indústria - serviços de utilida...
# 8568               PIBF  PIB Municipal - serviços - intermediação finan...
# 8569              PIBFE  PIB Estadual - serviços - intermediação financ...
# 8570               PIBG  PIB Municipal - serviços - administração públi...
# 8571              PIBGE  PIB Estadual - serviços - administração públic...
# 8572               PIBI  PIB Municipal - indústria - valor adicionado -...
# 8573              PIBIE  PIB Estadual - indústria - valor adicionado - ...
# 8574             PIBIEE  PIB Estadual - indústria - extrativa mineral -...
# 8575              PIBIN  PIB Municipal - indústria - transformação e ex...
# 8576             PIBITE  PIB Estadual - indústria - transformação - val...
# 8577              PIBOS  PIB Municipal - serviços - outros - valor adic...
# 8578             PIBOSE  PIB Estadual - serviços - outros - valor adici...
# 8579             PIBPCE                            PIB Estadual per capita
# 8580            PIBPMCE         PIB Estadual a preços de mercado  corrente
# 8581             PIBPOP  População preparada para o PIB Estadual(ponder...
# 8582             PIBSAE  PIB Estadual - serviços - outros - saúde e edu...
# 8583             PIBSCE  PIB Estadual - serviços - outros - outros serv...
# 8584             PIBSDE  PIB Estadual - serviços - outros - serviços do...
# 8585              PIBSE  PIB Municipal - serviços - valor adicionado - ...
# 8586             PIBSEE  PIB Estadual - serviços - valor adicionado - p...
# 8587             PIBSIU  PIB Municipal - indústria - serviços de utilid...
# 8588               PIBT  PIB Municipal - serviços - transporte, armazen...
# 8589             PIBTAE  PIB Estadual - serviços - transportes e comuni...
# 8590              PIBTE  PIB Estadual - serviços - transportes e comuni...
# 8591            PIBVRAE  PIB Estadual - valor adicionado a preços const...
# 8592           VPRODPIN              Valor da produção - Indústria - Total
#
# [8593 rows x 2 columns]

# %% [markdown]
# Let's suppose we are looking for a time series about GDP (PIB, in portuguese). We can filter the results of list_series() function by including a **keyword** to the parameters. This keyword will filter the results for only time series containing the specified keyword in their names:

# %%
idpy.list_series("PIB")
# Out:
#                  CODE                                               NAME
# 3747   WDI_PPCTAXAPIB    Taxa de paridade do poder de compra (PPC) - PIB
# 3748      BM_PIBUSDCM                                 PIB - câmbio médio
# 3749     BM_PIBUSDPPC  PIB - conceito: paridade do poder de compra (PPC)
# 3750       BM12_PIB12                                                PIB
# 3751     BM12_PIBAC12                                     PIB - 12 meses
# 3870        HIST_PIBR                                                PIB
# 3875       HIST_VAAGR      PIB - agricultura - índice (média 1939 = 100)
# 3876      HIST_VAAGRL       PIB - agricultura - valor adicionado líquido
# 3884       HIST_VACOM         PIB - comércio - índice (média 1939 = 100)
# 3891       HIST_VAGOV          PIB - governo - índice (média 1939 = 100)
# 3892      HIST_VAGOVL           PIB - governo - valor adicionado líquido
# 3895      HIST_VAINDL         PIB - indústria - valor adicionado líquido
# 3896      HIST_VAINDU        PIB - indústria - índice (média 1939 = 100)
# 3909      HIST_VATOTL                     PIB - valor adicionado líquido
# 3910   HIST_VATRANSCO  PIB - transportes e comunicações - índice (méd...
# 3911  HIST_VATRANSCOL  PIB - transportes e comunicações - valor adici...
# 3912        HIST_YAGG               PIB - agropecuária - var. real anual
# 3913       HIST_YINDG                  PIB - indústria - var. real anual
# 3914       HIST_YSERG                   PIB - serviços - var. real anual
# 3935      SCN_PIBPBN1  PIB - imputação de serviços intermediação fina...
# 3936    SCN10_AADMY10  PIB - serviços - administração, saúde e educaç...
# 3957   SCN10_DIPIBG10  PIB - preços de mercado - deflator implícito -...
# 3985      SCN10_PIB10  PIB - preços de mercado - índice (base 2010 = ...
# 3986     SCN10_PIBG10          PIB - preços de mercado - var. real anual
# 3987     SCN10_PIBN10                            PIB - preços de mercado
# 3988     SCN10_PIBP10              PIB - preços de mercado (preços 2010)
# 3989    SCN10_PIBPB10    PIB - preços básicos - índice (base 2010 = 100)
# 3990   SCN10_PIBPBG10             PIB - preços básicos - var. real anual
# 3991   SCN10_PIBPBN10                               PIB - preços básicos
# 3992   SCN10_PIBPBP10                 PIB - preços básicos (preços 2010)
# ...               ...                                                ...
# 8562           PIBCME  PIB Estadual - serviços - transportes e comuni...
# 8563           PIBCNE  PIB Estadual - indústria - construção - valor ...
# 8564            PIBCO  PIB Municipal - serviços - comércio - valor ad...
# 8565           PIBCOE  PIB Estadual - serviços - comércio - valor adi...
# 8566             PIBE                   PIB Estadual a preços constantes
# 8567          PIBEGAE  PIB Estadual - indústria - serviços de utilida...
# 8568             PIBF  PIB Municipal - serviços - intermediação finan...
# 8569            PIBFE  PIB Estadual - serviços - intermediação financ...
# 8570             PIBG  PIB Municipal - serviços - administração públi...
# 8571            PIBGE  PIB Estadual - serviços - administração públic...
# 8572             PIBI  PIB Municipal - indústria - valor adicionado -...
# 8573            PIBIE  PIB Estadual - indústria - valor adicionado - ...
# 8574           PIBIEE  PIB Estadual - indústria - extrativa mineral -...
# 8575            PIBIN  PIB Municipal - indústria - transformação e ex...
# 8576           PIBITE  PIB Estadual - indústria - transformação - val...
# 8577            PIBOS  PIB Municipal - serviços - outros - valor adic...
# 8578           PIBOSE  PIB Estadual - serviços - outros - valor adici...
# 8579           PIBPCE                            PIB Estadual per capita
# 8580          PIBPMCE         PIB Estadual a preços de mercado  corrente
# 8581           PIBPOP  População preparada para o PIB Estadual(ponder...
# 8582           PIBSAE  PIB Estadual - serviços - outros - saúde e edu...
# 8583           PIBSCE  PIB Estadual - serviços - outros - outros serv...
# 8584           PIBSDE  PIB Estadual - serviços - outros - serviços do...
# 8585            PIBSE  PIB Municipal - serviços - valor adicionado - ...
# 8586           PIBSEE  PIB Estadual - serviços - valor adicionado - p...
# 8587           PIBSIU  PIB Municipal - indústria - serviços de utilid...
# 8588             PIBT  PIB Municipal - serviços - transporte, armazen...
# 8589           PIBTAE  PIB Estadual - serviços - transportes e comuni...
# 8590            PIBTE  PIB Estadual - serviços - transportes e comuni...
# 8591          PIBVRAE  PIB Estadual - valor adicionado a preços const...
#
# [548 rows x 2 columns]

# %% [markdown]
# ***Observation:*** Pay attention to the case sensitiveness of the **keyword**. Uppercase/lowercase letters matters!

# %% [markdown]
# If you have a more specific need, you can use the parameters **code** or **name**. These parameters will filter the return to only exact matches with the specified **code**, **name** or both at the same time. For example, let's suppose that you have a time series name, say, *"Produção - calcário agrícola - qde."*, but you don't know his code. You can simply solve this problem doing:

# %%
idpy.list_series(name="Produção - calcário agrícola - qde.")
# Out:
#                  CODE                                 NAME
# 24  ABRACAL_PCALCARIO  Produção - calcário agrícola - qde.

# %% [markdown]
# Similarly, if you have a code, say, *GM366_ERC366*, and want to find the name of the time series associated to this code, you can simply do:

# %%
idpy.list_series(code="GM366_ERC366")
# Out:
#               CODE                                               NAME
# 3732  GM366_ERC366  Taxa de câmbio - R$ / US$ - comercial - compra...

# %% [markdown]
# You can also use both parameters together, despite the fact that this kind of usage seems to be useless (maybe it will be useful in the case of the existence of two different time series with the same name).

# %% [markdown]
# ## 1.1. Having an Overview of a Time Series

# %% [markdown]
# Now that you know how to find your desired time series and already have his code, maybe you have an interest in having an overview of his specific informations. For this purpose, there is a function called **describe()**. Let's have a look on *GM366_ERC366* time series:

# %%
idpy.describe("GM366_ERC366")
# Out:
#                Taxa de câmbio - R$ / US$ - comercial - compra - média
# Name            Taxa de câmbio - R$ / US$ - comercial - compra...
# Code                                                 GM366_ERC366
# Big Theme                                          Macroeconômico
# Theme                                                      Câmbio
# Source          Banco Central do Brasil, Sistema Gerenciador d...
# Source acronym                                   Bacen Outras/SGS
# Comment         Taxa de câmbio R$/US$ comercial (valor de comp...
# Last update                         2019-05-15T15:20:01.073-03:00
# Frequency                                                  Diária
# Measure                                                        R$
# Unit                                                         None
# Status                                                          A

# %% [markdown]
# ## 1.2. Checking Time Series' Data

# %% [markdown]
# To access the data of a specific time series we use the function called **timeseries()**. For the full set of data, you just need to specify the desired time series' code:

# %%
idpy.timeseries("GM366_ERC366")
# Out:
#        YEAR  DAY  MONTH          CODE                       DATE    VALUE (R$)
# 0      1985    2      1  GM366_ERC366  1985-01-02T00:00:00-02:00  1.152000e-09
# 1      1985    3      1  GM366_ERC366  1985-01-03T00:00:00-02:00  1.152000e-09
# 2      1985    4      1  GM366_ERC366  1985-01-04T00:00:00-02:00  1.152000e-09
# 3      1985    5      1  GM366_ERC366  1985-01-05T00:00:00-02:00           NaN
# 4      1985    6      1  GM366_ERC366  1985-01-06T00:00:00-02:00           NaN
# 5      1985    7      1  GM366_ERC366  1985-01-07T00:00:00-02:00  1.173818e-09
# 6      1985    8      1  GM366_ERC366  1985-01-08T00:00:00-02:00  1.173818e-09
# 7      1985    9      1  GM366_ERC366  1985-01-09T00:00:00-02:00  1.173818e-09
# 8      1985   10      1  GM366_ERC366  1985-01-10T00:00:00-02:00  1.173818e-09
# 9      1985   11      1  GM366_ERC366  1985-01-11T00:00:00-02:00  1.200364e-09
# 10     1985   12      1  GM366_ERC366  1985-01-12T00:00:00-02:00           NaN
# 11     1985   13      1  GM366_ERC366  1985-01-13T00:00:00-02:00           NaN
# 12     1985   14      1  GM366_ERC366  1985-01-14T00:00:00-02:00  1.200364e-09
# 13     1985   15      1  GM366_ERC366  1985-01-15T00:00:00-02:00  1.200364e-09
# 14     1985   16      1  GM366_ERC366  1985-01-16T00:00:00-02:00  1.227636e-09
# 15     1985   17      1  GM366_ERC366  1985-01-17T00:00:00-02:00  1.227636e-09
# 16     1985   18      1  GM366_ERC366  1985-01-18T00:00:00-02:00  1.227636e-09
#
# [92 rows x 6 columns]

# %% [markdown]
# If you just want the data for a specific month of a specific year, use both the parameters **year** and **month**:

# %%
idpy.timeseries("GM366_ERC366", year=2019, month=4)
# Out:
#        YEAR  DAY  MONTH          CODE                       DATE  VALUE (R$)
# 12139  2019    1      4  GM366_ERC366  2019-04-01T00:00:00-03:00      3.8676
# 12140  2019    2      4  GM366_ERC366  2019-04-02T00:00:00-03:00      3.8655
# 12141  2019    3      4  GM366_ERC366  2019-04-03T00:00:00-03:00      3.8430
# 12142  2019    4      4  GM366_ERC366  2019-04-04T00:00:00-03:00      3.8707
# 12143  2019    5      4  GM366_ERC366  2019-04-05T00:00:00-03:00      3.8616
# 12144  2019    8      4  GM366_ERC366  2019-04-08T00:00:00-03:00      3.8652
# 12145  2019    9      4  GM366_ERC366  2019-04-09T00:00:00-03:00      3.8557
# 12146  2019   10      4  GM366_ERC366  2019-04-10T00:00:00-03:00      3.8339
# 12147  2019   11      4  GM366_ERC366  2019-04-11T00:00:00-03:00      3.8393
# 12148  2019   12      4  GM366_ERC366  2019-04-12T00:00:00-03:00      3.8679
# 12149  2019   15      4  GM366_ERC366  2019-04-15T00:00:00-03:00      3.8724
# 12150  2019   16      4  GM366_ERC366  2019-04-16T00:00:00-03:00      3.8907
# 12151  2019   17      4  GM366_ERC366  2019-04-17T00:00:00-03:00      3.9219
# 12152  2019   18      4  GM366_ERC366  2019-04-18T00:00:00-03:00      3.9364
# 12153  2019   22      4  GM366_ERC366  2019-04-22T00:00:00-03:00      3.9224
# 12154  2019   23      4  GM366_ERC366  2019-04-23T00:00:00-03:00      3.9430
# 12155  2019   24      4  GM366_ERC366  2019-04-24T00:00:00-03:00      3.9624
# 12156  2019   25      4  GM366_ERC366  2019-04-25T00:00:00-03:00      3.9719
# 12157  2019   26      4  GM366_ERC366  2019-04-26T00:00:00-03:00      3.9347
# 12158  2019   29      4  GM366_ERC366  2019-04-29T00:00:00-03:00      3.9358
# 12159  2019   30      4  GM366_ERC366  2019-04-30T00:00:00-03:00      3.9447

# %%
idpy.timeseries("GM366_ERC366", year=2019, month=4).plot("DAY", "VALUE (R$)")

# %% [markdown]
# Similarly, if you just want the data for a specific day of a specific month of a specific year use together the parameters **year**, **month** and **day**:

# %%
idpy.timeseries("GM366_ERC366", year=2019, month=4, day=1)
# Out:
#        YEAR  DAY  MONTH          CODE                       DATE  VALUE (R$)
# 12139  2019    1      4  GM366_ERC366  2019-04-01T00:00:00-03:00      3.8676

# %% [markdown]
# Another example: returning only data relative to years greater than 2017:

# %%
idpy.timeseries("GM366_ERC366", yearGreaterThan=2013)
# Out:
#        YEAR  DAY  MONTH          CODE                       DATE  VALUE (R$)
# 10591  2014    1      1  GM366_ERC366  2014-01-01T00:00:00-02:00         NaN
# 10592  2014    2      1  GM366_ERC366  2014-01-02T00:00:00-02:00      2.3969
# 10593  2014    3      1  GM366_ERC366  2014-01-03T00:00:00-02:00      2.3734
# 10594  2014    4      1  GM366_ERC366  2014-01-04T00:00:00-02:00         NaN
# 12075  2018   27     12  GM366_ERC366  2018-12-27T00:00:00-02:00      3.9324
# 12076  2018   28     12  GM366_ERC366  2018-12-28T00:00:00-02:00      3.8742
# 12077  2018   31     12  GM366_ERC366  2018-12-31T00:00:00-02:00      3.8742
#
# [147 rows x 6 columns]

# %% [markdown]
# From now on, use your creativity. There are a lot of possibilities with these parameter combinations. The available parameters for the function **timeseries()** can be found using the function **help()**:

# %%
help(idpy.timeseries)
# Out:
# Help on function timeseries in module ipeadatapy.timeseries:
#
# timeseries(series, groupby=None, year=None, yearGreaterThan=None, yearSmallerThan=None, day=None, dayGreaterThan=None, daySmallerThan=None, month=None, monthGreaterThan=None, monthSmallerThan=None, code=None, date=None)
#     Returns the specified time series' data values. `series` must be a time series code
#     :param series: Time series code. For the available time series run list_series()
#     :type series: str
#     :param groupby: Grouping criteria
#     :type groupby: str, optional
#     :param year: Year which the data set will be restricted to.
#     :type year: int, optional
#     :param yearGreaterThan: Year which the data set will be restricted to years strictly greater.
#     :type yearGreaterThan: int, optional
#     :param yearSmallerThan: Year which the data set will be restricted to years strictly smaller.
#     :type yearSmallerThan: int, optional
#     :param day: Day which the data set will be restricted to.
#     :type day: int, optional
#     :param dayGreaterThan: Day which the data set will be restricted to days strictly greater.
#     :type dayGreaterThan: int, optional
#     :param daySmallerThan: Day which the data set will be restricted to days strictly smaller.
#     :type daySmallerThan: int, optional
#     :param month: Month which the data set will be restricted to.
#     :type month: int, optional
#     :param monthGreaterThan: Month which the data set will be restricted to months strictly greater.
#     :type monthGreaterThan: int, optional
#     :param monthSmallerThan: Month which the data set will be restricted to months strictly smaller.
#     :type monthSmallerThan: int, optional
#     :param code: Time series code which the data set will be restricted to.
#     :type code: str, optional
#     :param date: Date which the data set will be restricted to.
#     :type date: str, optional
#     :return: Returns the data series for the specified time series.
#     :rtype: pandas.DataFrame

# %% [markdown]
# # 2. INTERMEDIATE: Exploring Ipeadata Metadata

# %% [markdown]
# Every Ipeadata's time series is accompanied by a set of metadata. Some examples of the elements of this set of metadatas are: *country*, *big theme*, *theme*, *source*, *unit of measure*, *frequency* et cetera.

# %% [markdown]
# Some specific kinds of metadata have their own function on Ipeadata API. For example, you can have a look at the available Ipeadata's countries by running the **countries()** function:

# %%
idpy.countries()
# Out:
#       ID                         COUNTRY
# 0    ZAF                   África do Sul
# 1    DEU                        Alemanha
# 2   LATI                  América Latina
# 3    AGO                          Angola
# 4    SAU                  Arábia Saudita
# 5    DZA                         Argélia
# 6    ARG                       Argentina
# 7    AUS                       Austrália
# 8    AUT                         Áustria
# 9    BEL                         Bélgica
# 10   BOL                         Bolívia
# 11   BRA                          Brasil
# 12   CPV                      Cabo Verde
# 13   CAN                          Canadá
# 14   CHL                           Chile
# 15   CHN                           China
# 16   SGP                       Cingapura
# 17   COL                        Colômbia
# 18   COG                           Congo
# 19   KOR                   Coréia do Sul
# 20   DNK                       Dinamarca
# 21   ARE          Emirados Árabes Unidos
# 22   ECU                         Equador
# 23   ESP                         Espanha
# 24   USA                  Estados Unidos
# 25   RUS                 Federação Russa
# 26   FIN                       Finlândia
# 27   FRA                          França
# 28   GBR  Grã-Bretanha (Reino Unido, UK)
# 29   GRC                          Grécia
# ..   ...                             ...
# 37   IRL                         Irlanda
# 38   ISL                        Islândia
# 39   ISR                          Israel
# 40   ITA                          Itália
# 41   JPN                           Japão
# 42   LUX                      Luxemburgo
# 43   MAC                           Macau
# 44   MYS                         Malásia
# 45   MAR                        Marrocos
# 46   MEX                          Mexico
# 47   MOZ                      Moçambique
# 48  WRLD                         Mundial
# 49   MMR               Myanma (Ex-Burma)
# 50   NGA                         Nigéria
# 51   NOR                         Noruega
# 52   NZL                   Nova Zelândia
# 53  INDU         Países industrializados
# 54   PRY                        Paraguai
# 55   PER                            Peru
# 56   PRT                        Portugal
# 57   QAT                           Qatar
# 58   CZE                República Tcheca
# 59   STP             São Tomé e Príncipe
# 60   SWE                          Suécia
# 61   CHE                           Suíça
# 62   THA                       Tailândia
# 63   TLS     Timor Leste (Ex-East Timor)
# 64   URY                         Uruguai
# 65   VEN                       Venezuela
# 66  ZEUR                    Zona do Euro
#
# [67 rows x 2 columns]

# %% [markdown]
# Examples of utilities for the function **countries()** are: (...)

# %% [markdown]
# You can also have a look on the available themes for Ipeadata using the function **themes()**:

# %%
idpy.themes()
# Out:
#     ID                     NAME  MACRO  REGIONAL  SOCIAL
# 0   28             Agropecuária    NaN       1.0     NaN
# 1   23       Assistência social    NaN       NaN     1.0
# 2   25     Avaliação do governo    NaN       NaN     NaN
# 3   10    Balanço de pagamentos    1.0       NaN     NaN
# 4    7                   Câmbio    1.0       NaN     NaN
# 5    5        Comércio exterior    1.0       1.0     NaN
# 6    2         Consumo e vendas    1.0       1.0     NaN
# 7    8         Contas nacionais    1.0       NaN     NaN
# 8   81         Contas Regionais    NaN       1.0     NaN
# 9   24       Correção monetária    1.0       NaN     NaN
# 10  37               Demografia    NaN       NaN     1.0
# 11  54        Deputado Estadual    NaN       1.0     NaN
# 12  55         Deputado Federal    NaN       1.0     NaN
# 13  38   Desenvolvimento humano    NaN       NaN     1.0
# 14  11   Economia internacional    1.0       NaN     NaN
# 15  29                 Educação    NaN       NaN     1.0
# 16  18                 Eleições    NaN       NaN     NaN
# 17  63               Eleitorado    NaN       1.0     NaN
# 18  12                  Emprego    1.0       1.0     NaN
# 19  19       Estoque de capital    1.0       1.0     NaN
# 20   6        Finanças públicas    1.0       1.0     NaN
# 21  39              Financeiras    1.0       NaN     NaN
# 22  32               Geográfico    NaN       1.0     NaN
# 23  56               Governador    NaN       1.0     NaN
# 24  31                Habitação    NaN       NaN     1.0
# 25  80                 IDHm1991    NaN       NaN     NaN
# 26  79                 IDHm2000    NaN       NaN     1.0
# 27  78                 IDHm2010    NaN       NaN     NaN
# 28  15      Indicadores sociais    1.0       NaN     NaN
# 29   4                    Juros    NaN       NaN     NaN
# 30  40      Mercado de trabalho    NaN       NaN     1.0
# 31   3          Moeda e crédito    1.0       1.0     NaN
# 32  27  Percepção e expectativa    1.0       NaN     NaN
# 33  14                População    1.0       1.0     NaN
# 34   9                   Preços    1.0       1.0     NaN
# 35  57                 Prefeito    NaN       1.0     NaN
# 36  58               Presidente    NaN       1.0     NaN
# 37   1                 Produção    1.0       1.0     NaN
# 38  16                Projeções    1.0       NaN     NaN
# 39  30                    Renda    NaN       1.0     1.0
# 40  13          Salário e renda    1.0       NaN     NaN
# 41  41                    Saúde    NaN       NaN     1.0
# 42  20        Segurança Pública    NaN       1.0     NaN
# 43  59                  Senador    NaN       1.0     NaN
# 44  17   Sinopse macroeconômica    1.0       NaN     NaN
# 45  33               Transporte    1.0       1.0     NaN
# 46  26                   Vendas    NaN       1.0     NaN
# 47  60                 Vereador    NaN       1.0     NaN

# %% [markdown]
# Let's suppose you have the interest to know which of the themes of Ipeadata are related to the Macroeconomics big theme. The parameter **macro** will solve this problem:

# %%
idpy.themes(macro=1)
# Out:
#     ID                     NAME  MACRO  REGIONAL  SOCIAL
# 3   10    Balanço de pagamentos    1.0       NaN     NaN
# 4    7                   Câmbio    1.0       NaN     NaN
# 5    5        Comércio exterior    1.0       1.0     NaN
# 6    2         Consumo e vendas    1.0       1.0     NaN
# 7    8         Contas nacionais    1.0       NaN     NaN
# 9   24       Correção monetária    1.0       NaN     NaN
# 14  11   Economia internacional    1.0       NaN     NaN
# 18  12                  Emprego    1.0       1.0     NaN
# 19  19       Estoque de capital    1.0       1.0     NaN
# 20   6        Finanças públicas    1.0       1.0     NaN
# 21  39              Financeiras    1.0       NaN     NaN
# 28  15      Indicadores sociais    1.0       NaN     NaN
# 31   3          Moeda e crédito    1.0       1.0     NaN
# 32  27  Percepção e expectativa    1.0       NaN     NaN
# 33  14                População    1.0       1.0     NaN
# 34   9                   Preços    1.0       1.0     NaN
# 37   1                 Produção    1.0       1.0     NaN
# 38  16                Projeções    1.0       NaN     NaN
# 40  13          Salário e renda    1.0       NaN     NaN
# 44  17   Sinopse macroeconômica    1.0       NaN     NaN
# 45  33               Transporte    1.0       1.0     NaN

# %% [markdown]
# Let's now suppose that you just want the function to return **themes** that are related both to the macroeconomics and regional themes. For this, use **macro** and **regional** parameters together:

# %%
idpy.themes()
# Out:
#     ID                     NAME  MACRO  REGIONAL  SOCIAL
# 0   28             Agropecuária    NaN       1.0     NaN
# 1   23       Assistência social    NaN       NaN     1.0
# 2   25     Avaliação do governo    NaN       NaN     NaN
# 3   10    Balanço de pagamentos    1.0       NaN     NaN
# 4    7                   Câmbio    1.0       NaN     NaN
# 5    5        Comércio exterior    1.0       1.0     NaN
# 6    2         Consumo e vendas    1.0       1.0     NaN
# 7    8         Contas nacionais    1.0       NaN     NaN
# 8   81         Contas Regionais    NaN       1.0     NaN
# 9   24       Correção monetária    1.0       NaN     NaN
# 10  37               Demografia    NaN       NaN     1.0
# 11  54        Deputado Estadual    NaN       1.0     NaN
# 12  55         Deputado Federal    NaN       1.0     NaN
# 13  38   Desenvolvimento humano    NaN       NaN     1.0
# 14  11   Economia internacional    1.0       NaN     NaN
# 15  29                 Educação    NaN       NaN     1.0
# 16  18                 Eleições    NaN       NaN     NaN
# 17  63               Eleitorado    NaN       1.0     NaN
# 18  12                  Emprego    1.0       1.0     NaN
# 19  19       Estoque de capital    1.0       1.0     NaN
# 20   6        Finanças públicas    1.0       1.0     NaN
# 21  39              Financeiras    1.0       NaN     NaN
# 22  32               Geográfico    NaN       1.0     NaN
# 23  56               Governador    NaN       1.0     NaN
# 24  31                Habitação    NaN       NaN     1.0
# 25  80                 IDHm1991    NaN       NaN     NaN
# 26  79                 IDHm2000    NaN       NaN     1.0
# 27  78                 IDHm2010    NaN       NaN     NaN
# 28  15      Indicadores sociais    1.0       NaN     NaN
# 29   4                    Juros    NaN       NaN     NaN
# 30  40      Mercado de trabalho    NaN       NaN     1.0
# 31   3          Moeda e crédito    1.0       1.0     NaN
# 32  27  Percepção e expectativa    1.0       NaN     NaN
# 33  14                População    1.0       1.0     NaN
# 34   9                   Preços    1.0       1.0     NaN
# 35  57                 Prefeito    NaN       1.0     NaN
# 36  58               Presidente    NaN       1.0     NaN
# 37   1                 Produção    1.0       1.0     NaN
# 38  16                Projeções    1.0       NaN     NaN
# 39  30                    Renda    NaN       1.0     1.0
# 40  13          Salário e renda    1.0       NaN     NaN
# 41  41                    Saúde    NaN       NaN     1.0
# 42  20        Segurança Pública    NaN       1.0     NaN
# 43  59                  Senador    NaN       1.0     NaN
# 44  17   Sinopse macroeconômica    1.0       NaN     NaN
# 45  33               Transporte    1.0       1.0     NaN
# 46  26                   Vendas    NaN       1.0     NaN
# 47  60                 Vereador    NaN       1.0     NaN

# %% [markdown]
# The parameter **social** is also available and works in the same way of **macro** and **regional**. For more parameters available for the function **themes()** run **help(idpy.themes)**

# %% [markdown]
# Other important metadata is the source. This metadata have his own functions, **sources()**. Let's have a look:

# %%
idpy.sources()
# Out:
# 0                         Abia
# 1                       Abinee
# 2                         ABPO
# 3                      Abracal
# 4                        Abras
# 5                    ACSP/IEGV
# 6                         Anac
# 7                       Anatel
# 8                       Anbima
# 9                       Anbima
# 10                        Anda
# 11                     Anfavea
# 12                         ANP
# 13                   Antaq/AEP
# 14                   ANTT/AETT
# 15                 Assembleias
# 16            Bacen Outras/BPE
# 17             Bacen Outras/IA
# 18           Bacen Outras/Iceb
# 19             Bacen Outras/IE
# 20            Bacen Outras/ISP
# 21            Bacen Outras/SGS
# 22           Bacen Outras/SHFP
# 23     Bacen/Boletim/Ativ. Ec.
# 24            Bacen/Boletim/BP
# 25      Bacen/Boletim/Bpantigo
# 26       Bacen/Boletim/Intern.
# 27     Bacen/Boletim/M. Finan.
# 28             Bacen/BP (BPM5)
# 29             Bacen/BP (BPM6)
#                 ...
# 128           Min. Fazenda/STN
# 129           Min. Fazenda/STN
# 130              Min. Trabalho
# 131                 Minagincom
# 132                      MIVOP
# 133                        MME
# 134                        MPS
# 135                         MS
# 136                        MTE
# 137                  MTE/Caged
# 138                  MTE/Caged
# 139                 MTE/Outras
# 140                     Nasdaq
# 141                     Nectar
# 142                    Nemesis
# 143                       OCDE
# 144                        ONS
# 145                   ONU/LINK
# 146                   OUTFONTE
# 147              Outras fontes
# 148                  Procon-SP
# 149                      RFFSA
# 7              Municípios     3808.4   False
# 8              Municípios     2645.0   False
# 9              Municípios     1442.4   False
# 10             Municípios     3079.7   False
# 11             Municípios     5140.6   False
# 12              AMC 91-00     4523.8   False
# 13             Municípios     4523.8   False
# 14          Microrregiões    65905.9   False
# 15              AMC 91-00    25214.0   False
# 16             Municípios    25214.0   False
# 17             Municípios     2909.6   False
# 18              AMC 91-00     6922.5   False
# 19             Municípios     6922.5   False
# 20             Municípios     8556.1   False
# 21              AMC 91-00     1159.9   False
# 22             Municípios     1159.9   False
# 23             Municípios     1978.2   False
# 24             Municípios     6258.0   False
# 25          Microrregiões    41315.6   False
# 26             Municípios    34209.5    True
# 27              AMC 91-00     1693.4   False
# 28             Municípios     1693.4   False
# 29             Municípios     1729.9   False
# ...                   ...        ...     ...
# 19319           AMC 91-00     6891.7   False
# 19320           AMC 91-00      270.3   False
# 19321           AMC 91-00     2342.2   False
# 19322           AMC 91-00      334.4   False
# 19323           AMC 91-00     3088.8   False
# 19324           AMC 91-00     1487.6   False
# 19325           AMC 91-00     3155.1   False
# 19326           AMC 91-00     8834.3   False
# 19327           AMC 91-00     4617.5   False
# 19328           AMC 91-00     1131.8   False
# 19329           AMC 91-00     4264.7   False
# 19330           AMC 91-00      886.8   False
# 19331           AMC 91-00     2761.6   False
# 19332           AMC 91-00     4379.0   False
# 19333           AMC 91-00     6473.1   False
# 19334           AMC 91-00     9166.9   False
# 19335           AMC 91-00     1133.5   False
# 19336           AMC 91-00      495.1   False
# 19337           AMC 91-00     2140.3   False
# 19338             Estados     5822.1   False
# 19339  Área metropolitana     4004.5   False
# 19340  Área metropolitana     4004.5   False
# 19341           Estado/RM        0.0   False
# 19342           Estado/RM        0.0   False
# 19343       Microrregiões     5822.1   False
# 19344           AMC 91-00     5822.1   False
# 19345           AMC 60-00     5822.1    None
# 19346           AMC 70-00     5822.1   False
# 19347          Municípios     5822.1   False
# 19348        Mesorregiões     5822.1   False
#
# [19349 rows x 5 columns]

# %% [markdown]
# Two interesting parameters of **territories()** function are **areaGreaterThan** and **areaSmallerThan**. With these parameters, it is possible to filter the return of the function for just territories greater than, smaller than or between the specified parameters. For example, let's check which of the Brazilian territories have the area greater than 1000000:

# %%
idpy.territories(areaGreaterThan=1000000)
# Out:
#                       NAME                  ID        LEVEL       AREA CAPITAL
# 1                   Brasil                   0       Brasil  8531507.6   False
# 2             Região Norte                   1      Regiões  3869637.9   False
# 138               Amazonas                  13      Estados  1577820.2   False
# 386                   Pará                  15      Estados  1253164.5   False
# 1161       Região Nordeste                   2      Regiões  1558200.4   False
# 17960  Região Centro-oeste                   5      Regiões  1612077.2   False
# 18452     AMC1872_1997 001  513AMC1872_1997001  AMC 1872-00  1947986.1    None
# 18454          AMC2097 001        51AMC2097001    AMC 20-00  1061175.7    None

# %% [markdown]
# Let's now check the territories which the area is between 1000000 and 1100000:

# %%
idpy.territories(areaGreaterThan=1000000, areaSmallerThan=1500000)
# Out:
#               NAME            ID      LEVEL       AREA CAPITAL
# 386           Pará            15    Estados  1253164.5   False
# 18454  AMC2097 001  51AMC2097001  AMC 20-00  1061175.7    None

# %% [markdown]
# ## 2.1. Advanced Filtering Using Metadata

# %% [markdown]
# Now that you have knowledge of some of the metadata of Ipeadata, let's introduce yourself to a function called **metadata()**. This function returns all Ipeadata's time series in a data frame, similarly to the **list_series()** function. However, the difference between the two functions is that **metadata()** returns not only the time series but also their metadata. You might then be asking yourself why these two functions exists, since **metadata()** is a more complete version of the list_series function (**metadata()** features all of the **list_series()** information plus metadata). The answer is: **list_series()** is intended to be a more simplistic version, aiming unexperienced users and designed to be friendly to them. **metadata()**, in fact, is a more complete version as well as more confusing because of the quantity of information returned. No more words, let's run the function:

# %%
idpy.metadata()
# Out:
#            BIG THEME                                             SOURCE  \
# 0     Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 1     Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 2     Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 3     Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 4     Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 5     Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 6     Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 7     Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 8     Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 9     Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 10    Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 11    Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 12    Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 13    Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 14    Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 15    Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 16    Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 17    Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 18    Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 19    Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 20    Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 21    Macroeconômico  Instituto Brasileiro de Geografia e Estatístic...
# 22    Macroeconômico  Associação Brasileira das Indústrias da Alimen...
# 23    Macroeconômico  Associação Brasileira do Papelão Ondulado, Bol...
# 24    Macroeconômico  Associação Brasileira dos Produtores de Calcár...
# 25    Macroeconômico  Outras fontes, inclusive compilação de vários ...
# 26    Macroeconômico      Agência Nacional de Telecomunicações (Anatel)
# 27    Macroeconômico      Agência Nacional de Telecomunicações (Anatel)
# 28    Macroeconômico      Agência Nacional de Telecomunicações (Anatel)
# 29    Macroeconômico      Agência Nacional de Telecomunicações (Anatel)
# ...              ...                                                ...
# 8563        Regional   Instituto  Brasileiro de Geografia e Estatística
# 8564        Regional   Instituto  Brasileiro de Geografia e Estatística
# 8565        Regional   Instituto  Brasileiro de Geografia e Estatística
# 8566        Regional   Instituto  Brasileiro de Geografia e Estatística
# 19      IBGE/Coagro             www.ibge.gov.br      mil     BRA      Mensal
# 20      IBGE/Coagro             www.ibge.gov.br      mil     BRA      Mensal
# 21      IBGE/Coagro             www.ibge.gov.br      mil     BRA      Mensal
# 22             Abia             www.abia.org.br     None     BRA      Mensal
# 23             ABPO             www.abpo.org.br     None     BRA      Mensal
# 24          Abracal  http://www.abracal.com.br/      mil     BRA       Anual
# 25    Outras fontes                        None     None     BRA       Anual
# 26           Anatel           www.anatel.gov.br  milhões     BRA       Anual
# 27           Anatel           www.anatel.gov.br  milhões     BRA       Anual
# 28           Anatel           www.anatel.gov.br  milhões     BRA       Anual
# 29           Anatel           www.anatel.gov.br  milhões     BRA       Anual
# ...             ...                         ...      ...     ...         ...
# 8563           IBGE             www.ibge.gov.br      mil    None       Anual
# 8564           IBGE             www.ibge.gov.br      mil    None  Quinquenal
# 8565           IBGE             www.ibge.gov.br      mil    None       Anual
# 8566           IBGE             www.ibge.gov.br      mil    None       Anual
# 8567           IBGE             www.ibge.gov.br      mil    None       Anual
# 8568           IBGE             www.ibge.gov.br      mil    None  Quinquenal
# 8569           IBGE             www.ibge.gov.br      mil    None       Anual
# 8570           IBGE             www.ibge.gov.br      mil    None  Quinquenal
# 8571           IBGE             www.ibge.gov.br      mil    None       Anual
# 8572           IBGE             www.ibge.gov.br      mil    None  Quinquenal
# 8573           IBGE             www.ibge.gov.br      mil    None       Anual
# 8574           IBGE             www.ibge.gov.br      mil    None       Anual
# 8575           IBGE             www.ibge.gov.br      mil    None  Quinquenal
# 8576           IBGE             www.ibge.gov.br      mil    None       Anual
# 8577           IBGE             www.ibge.gov.br      mil    None  Quinquenal
# 8578           IBGE             www.ibge.gov.br      mil    None       Anual
# 8579           IBGE             www.ibge.gov.br      mil    None       Anual
# 8580           IBGE             www.ibge.gov.br      mil    None       Anual
# 8581           IBGE             www.ibge.gov.br     None    None       Anual
# 8582           IBGE             www.ibge.gov.br      mil    None       Anual
# 8583           IBGE             www.ibge.gov.br      mil    None       Anual
# 8584           IBGE             www.ibge.gov.br      mil    None       Anual
# 8585           IBGE             www.ibge.gov.br      mil    None  Quinquenal
# 8586           IBGE             www.ibge.gov.br      mil    None       Anual
# 8587           IBGE             www.ibge.gov.br      mil    None  Quinquenal
# 8588           IBGE             www.ibge.gov.br      mil    None  Quinquenal
# 8589           IBGE             www.ibge.gov.br      mil    None       Anual
# 8590           IBGE             www.ibge.gov.br      mil    None       Anual
# 8591           IBGE             www.ibge.gov.br     None    None       Anual
# 8592           IBGE             www.ibge.gov.br     None    None   Irregular
#
#                         LAST UPDATE               CODE  \
# 0     2019-03-15T19:10:01.223-03:00       ABATE_ABPEAV
# 1     2019-03-15T19:10:01.223-03:00       ABATE_ABPEBV
# 2     2019-03-15T19:10:01.223-03:00       ABATE_ABPESU
# 3     2019-03-15T19:10:01.223-03:00       ABATE_ABQUAV
# 4     2019-03-15T19:10:01.223-03:00       ABATE_ABQUBV
# 5     2019-03-15T19:10:01.223-03:00       ABATE_ABQUSU
# 6         2009-07-29T14:54:55-03:00   ABATE12_ABPEAV12
# 8586  2013-09-12T16:17:24.653-03:00             PIBSEE
# 8587   2013-06-20T11:59:20.01-03:00             PIBSIU
# 8588   2013-06-20T11:59:20.01-03:00               PIBT
# 8589  2013-09-12T16:17:24.653-03:00             PIBTAE
# 8590  2013-09-12T16:17:24.653-03:00              PIBTE
# 8591   2015-03-13T18:00:58.15-03:00            PIBVRAE
# 8592  2011-05-12T12:51:02.437-03:00           VPRODPIN
#
#                                                 COMMENT  \
# 0     Fontes: Para 1975 - 1996: Pesquisa Mensal de A...
# 1     Fontes:  Para 1975 - 1996: Pesquisa Mensal de ...
# 2     Fontes:  Para 1975 - 1996: Pesquisa Mensal de ...
# 3     Fontes:  Para 1975 - 1996: Pesquisa Mensal de ...
# 4     Fontes:  Para 1975 - 1996: Pesquisa Mensal de ...
# 5     Fontes:  Para 1975 - 1996: Pesquisa Mensal de ...
# 6     Fonte: Para 1975 - 1996: Pesquisa Mensal de Ab...
# 7     Fonte: Para 1975 - 1996: Pesquisa Mensal de Ab...
# 8     Fonte: Para 1975 - 1996: Pesquisa Mensal de Ab...
# 9     Fonte: Para 1975 - 1996: Pesquisa Mensal de Ab...
# 10    A partir de 1997 a pesquisa passou a ser trime...
# 11    Fonte: Para 1975 - 1996: Pesquisa Mensal de Ab...
# 12    Fonte: Para 1975 - 1996: Pesquisa Mensal de Ab...
# 13    Fonte: Para 1975 - 1996: Pesquisa Mensal de Ab...
# 14    Fonte: Para 1975 - 1996: Pesquisa Mensal de Ab...
# 15    Fonte: Para 1975 - 1996: Pesquisa Mensal de Ab...
# 16    Fonte: Para 1975 - 1996: Pesquisa Mensal de Ab...
# 17    Fonte: Para 1975 - 1996: Pesquisa Mensal de Ab...
# 18    A partir de 1997 a pesquisa passou a ser trime...
# 19    Fonte: Para 1975 - 1996: Pesquisa Mensal de Ab...
# 20    Fonte: Para 1975 - 1996: Pesquisa Mensal de Ab...
# 21    Fonte: Para 1975 - 1996: Pesquisa Mensal de Ab...
# 22    Quadro: Pesquisa conjuntural da indústria da a...
# 23    Dados a partir de jan/2005 revisados pela font...
# 24    Os solos do Brasil são em geral muito ácidos, ...
# 25    Fontes: Para 1976-1987: Anuário Estatístico do...
# 26    Um acesso, termo adotado no Relatório Anual da...
# 27    Um acesso, termo adotado no Relatório Anual da...
# 28    Corresponde, no Relatório Anual da Anatel, ao ...
# 29    Corresponde ao "total de telefones" apresentad...
# ...                                                 ...
# 8563  Fontes: Para 2002-2006: Sistema de Contas Regi...
# 8564  Fonte: Para os anos censitários de 1970 a 1996...
# 8565  Fontes: Para 2002-2006: Sistema de Contas Regi...
# 8566  Até 1985 não há dados para todos os anos. Cálc...
# 8567  Fontes: Para 2002-2006: Sistema de Contas Regi...
# 8568  Fonte: Para os anos censitários de 1970 a 1996...
# 8569  Fontes: Para 2002-2006: Sistema de Contas Regi...
# 8570  Fontes: Para 1999-2007: Sistema de Contas Regi...
# 8571  Fontes: Para 2002-2006: Sistema de Contas Regi...
# 8572  Fontes: Para 1999-2007: Sistema de Contas Regi...
# 8573  Fontes: Para 2002-2006: Sistema de Contas Regi...
# 8574  Fontes: Para 2002-2006: Sistema de Contas Regi...
# 8575  Fonte: Para os anos censitários de 1970 a 1996...
# 8576  Fontes: Para 2002-2006: Sistema de Contas Regi...
# 8577  Fonte: Para os anos censitários de 1970 a 1996...
# 8578  Fontes: Para 2002-2006: Sistema de Contas Regi...
# 8579  Fonte: PIB Estadual a preços constantes (série...
# 8580  Fonte: IPEA, a partir de dados do IBGE. Até 19...
# 8581                                               None
# 8582  Fontes: Para 2002-2006: Sistema de Contas Regi...
# 8583  Fontes: Para 2002-2006: Sistema de Contas Regi...
# 8584  Fontes: Para 2002-2006: Sistema de Contas Regi...
# 8585  Fontes: Para 1999-2007: Sistema de Contas Regi...
# 8586  Fontes: Para 2002-2006: Sistema de Contas Regi...
# 8587  Fonte: Para os anos censitários de 1970 a 1996...
# 8588  Fonte: Para os anos censitários de 1970 a 1996...
# 8589  Fontes: Para 2002-2006: Sistema de Contas Regi...
# 8590  Fontes: Para 2002-2006: Sistema de Contas Regi...
# 8591  Fonte: IPEA, a partir de dados do IBGE. Trata-...
# 8592  Os municípios da tabela não necessariamente co...
#
#                                                    NAME  NUMERICA  \
# 0               Abate - aves - peso das carcaças - qde.      True
# 1            Abate - bovinos - peso das carcaças - qde.      True
# 2             Abate - suínos - peso das carcaças - qde.      True
# 3                                   Abate - aves - qde.      True
# 4                                Abate - bovinos - qde.      True
# 5                                 Abate - suínos - qde.      True
# 6               Abate - aves - peso das carcaças - qde.      True
# 7               Abate - bois - peso das carcaças - qde.      True
# 8            Abate - bovinos - peso das carcaças - qde.      True
# 9            Abate - frangos - peso das carcaças - qde.      True
# 10          Abate - novilhos - peso das carcaças - qde.      True
# 11            Abate - suínos - peso das carcaças - qde.      True
# 12             Abate - vacas - peso das carcaças - qde.      True
# 13           Abate - vitelos - peso das carcaças - qde.      True
# 14                                  Abate - aves - qde.      True
# 15                                  Abate - bois - qde.      True
# 16                               Abate - bovinos - qde.      True
# 17                               Abate - frangos - qde.      True
# 18                              Abate - novilhos - qde.      True
# 19                                Abate - suínos - qde.      True
# 20                                 Abate - vacas - qde.      True
# 21                               Abate - vitelos - qde.      True
# 22    Produção física - alimentos - índice (média 19...      True
# 23    Expedição de caixas, acessórios e chapas - pap...      True
# 24                  Produção - calcário agrícola - qde.      True
# 25                      Telefone - aparelhos instalados      True
# 26                  Telefone - acessos fixos instalados      True
# 27                  Telefone - acessos fixos em serviço      True
# 28                 Telefone - acessos móveis em serviço      True
# 29         Telefone - acessos móveis e fixos em serviço      True
# ...                                                 ...       ...
# 8563  PIB Estadual - indústria - construção - valor ...      True
# 8564  PIB Municipal - serviços - comércio - valor ad...      True
# 8565  PIB Estadual - serviços - comércio - valor adi...      True
# 8566                   PIB Estadual a preços constantes      True
# 8567  PIB Estadual - indústria - serviços de utilida...      True
# 8568  PIB Municipal - serviços - intermediação finan...      True
# 8569  PIB Estadual - serviços - intermediação financ...      True
# 8570  PIB Municipal - serviços - administração públi...      True
# 8571  PIB Estadual - serviços - administração públic...      True
# 8572  PIB Municipal - indústria - valor adicionado -...      True
# 8573  PIB Estadual - indústria - valor adicionado - ...      True
# 8574  PIB Estadual - indústria - extrativa mineral -...      True
# 8575  PIB Municipal - indústria - transformação e ex...      True
# 8576  PIB Estadual - indústria - transformação - val...      True
# 8577  PIB Municipal - serviços - outros - valor adic...      True
# 8578  PIB Estadual - serviços - outros - valor adici...      True
# 8579                            PIB Estadual per capita      True
# 8580         PIB Estadual a preços de mercado  corrente      True
# 8581  População preparada para o PIB Estadual(ponder...      True
# 8582  PIB Estadual - serviços - outros - saúde e edu...      True
# 8583  PIB Estadual - serviços - outros - outros serv...      True
# 8584  PIB Estadual - serviços - outros - serviços do...      True
# 8585  PIB Municipal - serviços - valor adicionado - ...      True
# 8586  PIB Estadual - serviços - valor adicionado - p...      True
# 8587  PIB Municipal - indústria - serviços de utilid...      True
# 8588  PIB Municipal - serviços - transporte, armazen...      True
# 8589  PIB Estadual - serviços - transportes e comuni...      True
# 8590  PIB Estadual - serviços - transportes e comuni...      True
# 8591  PIB Estadual - valor adicionado a preços const...      True
# 8592              Valor da produção - Indústria - Total      True
#
#      SERIES STATUS  THEME CODE                   MEASURE
# 0                A           1                  Tonelada
# 1                A           1                  Tonelada
# 2                A           1                  Tonelada
# 3                A           1                    Cabeça
# 4                A           1                    Cabeça
# 5                A           1                    Cabeça
# 6                I           1                  Tonelada
# 7                A           1                  Tonelada
# 8                A           1                  Tonelada
# 9                A           1                  Tonelada
# 10               A           1                  Tonelada
# 11               A           1                  Tonelada
# 12               A           1                  Tonelada
# 13               I           1                  Tonelada
# 14               I           1                    Cabeça
# 15               A           1                    Cabeça
# 16               A           1                    Cabeça
# 17               A           1                    Cabeça
# 18               A           1                    Cabeça
# 19               A           1                    Cabeça
# 20               A           1                    Cabeça
# 21               I           1                    Cabeça
# 22               A           1                         -
# 23               A           1                  Tonelada
# 24               A           1                  Tonelada
# 25               I           1                   Unidade
# 26               I           1                   Unidade
# 27               A           1                   Unidade
# 28               A           1                   Unidade
# 29               A           1                   Unidade
# ...            ...         ...                       ...
# 8563          None          81  R$, a preços do ano 2000
# 8564          None          81  R$, a preços do ano 2000
# 8565          None          81  R$, a preços do ano 2000
# 8566          None          81                R$ de 2010
# 8567          None          81  R$, a preços do ano 2000
# 8568          None          81  R$, a preços do ano 2000
# 8569          None          81  R$, a preços do ano 2000
# 8570          None          81  R$, a preços do ano 2000
# 8571          None          81  R$, a preços do ano 2000
# 8572          None          81  R$, a preços do ano 2000
# 8573          None          81  R$, a preços do ano 2000
# 8574          None          81  R$, a preços do ano 2000
# 8575          None          81  R$, a preços do ano 2000
# 8576          None          81  R$, a preços do ano 2000
# 8577          None          81  R$, a preços do ano 2000
# 8578          None          81  R$, a preços do ano 2000
# 8579          None          81                R$ de 2010
# 8580          None          81                        R$
# 8581          None          81                    Pessoa
# 8582          None          81  R$, a preços do ano 2000
# 8583          None          81  R$, a preços do ano 2000
# 8584          None          81  R$, a preços do ano 2000
# 8585          None          81  R$, a preços do ano 2000
# 8586          None          81  R$, a preços do ano 2000
# 8587          None          81  R$, a preços do ano 2000
# 8588          None          81  R$, a preços do ano 2000
# 8589          None          81  R$, a preços do ano 2000
# 8590          None          81  R$, a preços do ano 2000
# 8591          None          81               Porcentagem
# 8592          None          81                R$ de 1999
#
# [8593 rows x 15 columns]

# %% [markdown]
# But why is this function so powerful and important? The first obvious answer is: it gives you more informations about time series. The not-so-obvious answer is: it allows you to better filter time series from Ipeadata. Let's state an illustrative problem for better understanding:

# %% [markdown]
# *Ipeadata API has 8565 time series in total. Let's suppose you are doing research in macroeconomics about the United States, but for some specific reason, your interest in data is restricted to data published by The Economist. It also needs to be quarterly published. How to solve this problem using ipeadatapy Python package?*

# %%
idpy.metadata(big_theme="Macroeconômico", country="USA", source="Economist", frequency="Trimestral")
# Out:
#            BIG THEME         SOURCE SOURCE ACRONYM         SOURCE URL  \
# 5629  Macroeconômico  The Economist      Economist  www.economist.com
# 5630  Macroeconômico  The Economist      Economist  www.economist.com
# 5631  Macroeconômico  The Economist      Economist  www.economist.com
#
#          UNIT COUNTRY   FREQUENCY                    LAST UPDATE  \
# 5629  bilhões     USA  Trimestral      2018-12-29T07:52:01-02:00
# 5630     None     USA  Trimestral  2019-03-18T13:58:01.433-03:00
# 5631     None     USA  Trimestral  2019-03-18T13:58:01.433-03:00
#
#                   CODE                          COMMENT  \
# 5629    ECONMI4_USCCY4  Série descontinuada pela fonte.
# 5630  ECONMI4_USPIBG34     Produto Interno Bruto (PIB).
# 5631   ECONMI4_USPIBG4     Produto Interno Bruto (PIB).
#
#                                                    NAME  NUMERICA  \
# 5629  balanço - conta corrente - saldo (acum. 12 meses)      True
# 5630                PIB - var. real trimestral anualiz.      True
# 5631  PIB - var. real contra igual trimestre do ano ...      True
#
#      SERIES STATUS  THEME CODE   MEASURE
# 5629             I          11       US$
# 5630             A          11  (% a.a.)
# 5631             A          11  (% a.a.)

# %% [markdown]
# *Gotcha!* Other metadata also can be used as filtering parameters. For all parameters run help(idpy.metadata).

# %%
help(idpy.metadata)
# Out:
# Help on function metadata in module ipeadatapy.metadata:
#
# metadata(series=None, big_theme=None, source=None, country=None, frequency=None, unit=None, measure=None, status=None, source_ext=None, source_url=None, last_update=None, code=None, comment=None, name=None, numerica=None, theme_id=None)
#     :param series: Time series code.
#     :type series: str, optional
#     :param big_theme: Big theme by which the return will be fitered. Options: "Macroeconômico", "Regional" or "Social"
#     :type big_theme: str, optional
#     :param source: Source by which the return will be filtered. For available sources run sources() function.
#     :type source: str, optional
#     :param country: Country ID by which the return will be filtered. For available countries and their IDs run countries() function.
#     :type country: str, optional
#     :param frequency: Frequency by which the return will be filtered.
#     :type frequency: str, optional
#     :param unit: Unit by which the return will be filtered.
#     :type unit: str, optional
#     :param measure: Measure by which the return will be filtered.
#     :type measure: str, optional
#     :param status: Status by which the return will be filtered. Available options: "A" and "I"
#     :type status: str, optional
#     :param source_ext: Source extended name by which the return will be filtered.
#     :type source_ext: str, optional
#     :param source_url: Source URL by which the return will be filtered.
#     :type source_url: str, optional
#     :param last_update: Last update date by which the return will be filtered.
#     :type last_update: str, optional
#     :param code: Time series code by which the return will be filtered.
#     :type code: str, optional
#     :param comment: Time series comment by which the return will be filtered.
#     :type comment: str, optional
#     :param name: Time series name by which the return will be filtered.
#     :type name: str, optional
#     :param numerica: Numeric? True or False.
#     :type numerica: bool, optional
#     :param theme_id: Theme by which the return will be filtered. For available themes run themes() function
#     :type theme_id: str, optional
#     :return: If no keyword is specified, returns a data frame containing all Ipeadata's time series. Else, returns only the ones that respects the specified parameters
#     :rtype: pandas.DataFrame

# %% [markdown]
# # 3. Extracting Data

# %% [markdown]
# In this example we will extract GM366_ERC366 time series data for april of 2019 in the format of a csv file (;-separated) named as "FileName.csv" to the same folder where this Python notebook is running.

# %%
idpy.timeseries("GM366_ERC366", year=2019, month=4).to_csv("FileName.csv", sep=";")

# %% [markdown]
# Another option is to extract the time series as a xlsx file:

# %%
idpy.timeseries("GM366_ERC366", year=2019, month=4).to_excel("FileName.xlsx")

# %% [markdown]
# # 4. ADVANCED: Doing from Scratch

# %% [markdown]
# http://ipeadata2-homologa.ipea.gov.br/api/

# %% [markdown]
# Use idpy.api_call(). Example:

# %%
idpy.api_call("http://ipeadata2-homologa.ipea.gov.br/api/v1/Paises")
# Out:
#    PAICODIGO                         PAINOME
# 0        ZAF                   África do Sul
# 1        DEU                        Alemanha
# 2       LATI                  América Latina
# 3        AGO                          Angola
# 4        SAU                  Arábia Saudita
# 5        DZA                         Argélia
# 6        ARG                       Argentina
# 7        AUS                       Austrália
# 8        AUT                         Áustria
# 9        BEL                         Bélgica
# 10       BOL                         Bolívia
# 11       BRA                          Brasil
# 12       CPV                      Cabo Verde
# 13       CAN                          Canadá
# 14       CHL                           Chile
# 15       CHN                           China
# 16       SGP                       Cingapura
# 17       COL                        Colômbia
# 18       COG                           Congo
# 19       KOR                   Coréia do Sul
# 20       DNK                       Dinamarca
# 21       ARE          Emirados Árabes Unidos
# 22       ECU                         Equador
# 23       ESP                         Espanha
# 24       USA                  Estados Unidos
# 25       RUS                 Federação Russa
# 26       FIN                       Finlândia
# 27       FRA                          França
# 28       GBR  Grã-Bretanha (Reino Unido, UK)
# 29       GRC                          Grécia
# ..       ...                             ...
# 37       IRL                         Irlanda
# 38       ISL                        Islândia
# 39       ISR                          Israel
# 40       ITA                          Itália
# 41       JPN                           Japão
# 42       LUX                      Luxemburgo
# 43       MAC                           Macau
# 44       MYS                         Malásia
# 45       MAR                        Marrocos
# 46       MEX                          Mexico
# 47       MOZ                      Moçambique
# 48      WRLD                         Mundial
# 49       MMR               Myanma (Ex-Burma)
# 50       NGA                         Nigéria
# 51       NOR                         Noruega
# 52       NZL                   Nova Zelândia
# 53      INDU         Países industrializados
# 54       PRY                        Paraguai
# 55       PER                            Peru
# 56       PRT                        Portugal
# 57       QAT                           Qatar
# 58       CZE                República Tcheca
# 59       STP             São Tomé e Príncipe
# 60       SWE                          Suécia
# 61       CHE                           Suíça
# 62       THA                       Tailândia
# 63       TLS     Timor Leste (Ex-East Timor)
# 64       URY                         Uruguai
# 65       VEN                       Venezuela
# 66      ZEUR                    Zona do Euro
#
# [67 rows x 2 columns]
